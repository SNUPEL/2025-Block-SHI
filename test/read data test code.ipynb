# %%
import pandas as pd
import os

# %%
filepath = '../data/data.xlsx'

# %%
df = pd.read_excel(filepath, sheet_name=None, skiprows=[1])
sheet_name_list = list(df.keys())

# %%
df[sheet_name_list[0]]
# Out:
#    그룹ID  우선순위  옥내외 러그고려 정반연결축  사이즈제한LTH  사이즈제한BTH  사이즈제한HGT  사이즈제한WGT TP운송여부  \
# 0     1     1  IDR    N     B        10         8         2        30      N
# 1     2     3  ODR    N     B        11        11         4        38      N
# 2     3     2  IDR    L    LB         8        11         3        38      N
# 3     4     4  ODR    N     L         0         0         0         0      Y
# 4     5     5  ODR    N   NaN         8        11         3        38      N
# 5     6     6  ODR    N   NaN         0         0         0         0      N
# 6     7     7  ODR    N   NaN         0         0         0         0      Y
#
#   사용여부
# 0    Y
# 1    Y
# 2    Y
# 3    Y
# 4    N
# 5    N
# 6    N
